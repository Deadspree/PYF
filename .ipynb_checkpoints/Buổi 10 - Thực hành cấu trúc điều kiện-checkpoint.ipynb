# %% [markdown]
# # Thực hành cấu trúc điều khiển
#
# ### Bài 1
#
# Cho phương trình bậc 2: ax^2 + bx + c = 0
#
# Nhập a, b, c
#
# Giải và biện luận phương trình trên

# %%
print("Giải PT bậc 2: ax^2 + bx + c = 0")
a = float(input("Nhập a: "))
b = float(input("Nhập b: "))
c = float(input("Nhập c: "))

if a == 0: ## bx + c = 0
    if b == 0:
        if c == 0: ## 0 = 0
            print("Phương trình vô số nghiệm")
        else:
            print("Phương trình vô nghiệm")
    else:
        print("Đây là phương có 1 nghiệm x = ", -c/b)
else:
    delta = b**2 - 4*a*c
    if delta > 0:
        candelta = delta**0.5
        x1 = (-b+candelta)/(2*a)
        x2 = (-b-candelta)/(2*a)
        print("Đây là phương trình có 2 nghiệm phân biệt:",x1,"và",x2)
    elif delta == 0:
        x = -b/(2*a)
        print("Đây là phương trình có 1 nghiệm kép:",x)
    else:
        print("Đây là phương trình vô nghiệm")
# Out:
# a= 1
# b= -2
# c= 3
# Phương trình vô nghiệm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bài 2
#
# Hãy nhập vào một số
#
# Xác định coi đó có phải là số nguyên tố hay không

# %%
a = int(input('Nhập a:'))
n = 1
kiemtra = False

for i in range(a-2):
    n +=1
    check= a%n==0
    kiemtra = kiemtra or check

if str(kiemtra) == "False":
    print('Đây là số nguyên tố')
else:
    print('Đây không phải là số nguyên tố')
# Out:
# Nhập a:7
# Đây là số nguyên tố

# %%
a = int(input())

u = 1
s = 0
for i in range(a):
    if a % u == 0:
        s += 1
    u += 1
    
if s == 2:
    print("Số nguyên tố")
else:
    print("Không phải số nguyên tố")
# Out:
# 5
# Số nguyên tố

# %% [markdown]
# ### Bài 3
#
# Hãy nhập vào số n
#
# Hãy đếm số chữ số 0 tận cùng của n giai thừa
#
# (Bài này nâng cao, mọi người có thể bỏ qua)

# %%
n = int(input("Nhập vào số n: "))
S = 1
b = 1
for i in range(n):
    S*= b
    b+=1
    
S = str(S)
c = -1
count_latter_zero = 0

for n in range(len(S)):
    if S[c] == "0":
        count_latter_zero += 1
        c -= 1
    
print(count_latter_zero, "số 0 ở cuối")
# Out:
# Nhập vào số n: 5
# 1 số 0 ở cuối

# %% [markdown]
# ### Bài 4
#
# In ra tất cả các số chia hết cho 3 nhỏ hơn 100

# %%
for i in range(0,100):
    if i%3==0:
        print(i)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# ### Bài 5
#
# In ra tất cả các số lẻ nhưng không chia hết cho 3 nhỏ hơn 100

# %%
for i in range(0,100):
    if i%2==1 and i%3!=0:
        print(i)
# Out:
# 1
# 5
# 7
# 11
# 13
# 17
# 19
# 23
# 25
# 29
# 31
# 35
# 37
# 41
# 43
# 47
# 49
# 53
# 55
# 59
# 61
# 65
# 67
# 71
# 73
# 77
# 79
# 83
# 85
# 89
# 91
# 95
# 97

# %% [markdown]
# ### Bài 5
#
# Tại một cửa hàng nọ có menu như sau:
#
# 1. Gà rán giá 35k
# 2. Hamburger giá 50k
# 3. Pesi giá 10k
#
# Nhập số lượng món hàng cần mua
#
# Tính và in ra tổng giá tiền (hiển thị có dấu chấm mỗi 3 chữ số để người dùng để quan sát)
#
# Nếu giá trị đơn hàng trên 2 triệu, giảm 10% cho khách, trên 4 triệu, giảm 15%
#
# Tính và in ra tổng giá tiền được giảm (hiển thị có dấu chấm mỗi 3 chữ số để người dùng để quan sát)
#
# Tính và in ra tổng giá tiền khách cần trả (hiển thị có dấu chấm mỗi 3 chữ số để người dùng để quan sát)
#
# In ra dòng chữ "Cảm ơn quý khách đã mua hàng"

# %%
soga = int(input("Số gà muốn mua: "))
ham = int(input("Số Hamburger muốn mua: "))
pesi = int(input("Số Pesi muốn mua: "))
total = 35000*soga + 50000*ham + 10000*pesi
duocgiam = 0
phaitra = 0

if total >2000000:
    duocgiam = total*0.1
    phaitra = total - duocgiam
elif total > 4000000:
    duocgiam = total*0.15
    phaitra = total - duocgiam
total = str(total)
a = -3
x = "."
y = x.strip()
for i in range(int(len(total)/3)):
    total = total[:(a-1)+(i*(-3))],y,total[a+((i*-3))]
    
print(total)
# Out:
# Số gà muốn mua: 30
# Số Hamburger muốn mua: 30
# Số Pesi muốn mua: 30
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6600/1442795410.py in <module>
#      17 y = x.strip()
#      18 for i in range(int(len(total)/3)):
# ---> 19     total = total[:(a-1)+(i*(-3))],y,total[a+((i*-3))]
#      20
#      21 print(total)
#
# IndexError: tuple index out of range

# %%
txt = "banana"

x = txt.strip()

print("of all fruits", x, "is my favorite")
# Out:
# of all fruits banana is my favorite

# %%
# Out:
# 12

# %% [markdown]
# ### Bài 6
#
# Nhập vào chiều cao (cm) và cân nặng (kg), tính số BMI và xét rồi xin kết quả theo dữ liệu sau:
#
# - BMI < 16: Gầy cấp độ III
# - 16 <= BMI < 17:  Gầy cấp độ II
# - 17<= BMI < 18.5: Gầy cấp độ I
# - 18.5 <= BMI < 25: Bình thường
# - 25 <= BMI < 30: Thừa cân
# - 30 <= BMI < 35 : Béo phì cấp độ I
# - 35 <= BMI < 40: Béo phì cấp độ II
# - BMI > 40: Béo phì cấp độ III

# %%
h = float(input("Nhập chiều cao: "))
w = float(input("Nhập cân nặng: "))

bmi = w/((h/100)**2)
if bmi < 16:
    print("Gầy cấp độ III")
elif bmi < 17:
    print("Gầy cấp độ II")
elif bmi < 18.5:
    print("Gầy cấp độ I")
elif bmi < 25:
    print("Bình thường")
elif bmi < 30:
    print("Thừa cân")
elif bmi < 35:
    print("Béo phì cấp độ I")
elif bmi < 40:
    print("Béo phì cấp độ II")
else:
    print("Béo phì cấp độ III")

# %% [markdown]
# ### Bài 7
#
# Nhập ngày, tháng, năm. Hãy tính và in ra màn hình kể từ đầu năm đến ngày vừa nhập là bao nhiêu ngày.
